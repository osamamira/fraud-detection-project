# %% [markdown]
# # Credit Card Transactions Dataset
#
# The Credit Card Transactions Dataset provides detailed records of credit card transactions, including information about transaction times, amounts, and associated personal and merchant details. This dataset has over 1,296,675 rows.
#
# ## Data Columns
#
# ### 1. trans_date_trans_time
# - **Description**: This column contains the date and time of the transaction.
# - **Type**: Timestamp or string (depending on how it's formatted).
# - **Usage**: Useful for analyzing transaction patterns over time, such as daily/weekly/monthly trends or detecting anomalies during specific periods.
#
# ### 2. cc_num
# - **Description**: The credit card number associated with the transaction.
# - **Type**: Numeric or string (if padded with leading zeros).
# - **Usage**: Identifies the specific credit card used in the transaction. Can be used to track transactions made by the same card.
#
# ### 3. merchant
# - **Description**: The name or identifier of the merchant where the transaction occurred.
# - **Type**: String.
# - **Usage**: Helps categorize transactions based on the merchant and can be useful for fraud detection if certain merchants are flagged as high-risk.
#
# ### 4. category
# - **Description**: The category of the merchant or the type of purchase (e.g., "grocery", "travel", "entertainment").
# - **Type**: Categorical (string).
# - **Usage**: Provides insight into the nature of the transaction and can help identify unusual spending behavior.
#
# ### 5. amt
# - **Description**: The amount of money involved in the transaction.
# - **Type**: Numeric (float or integer).
# - **Usage**: Critical for fraud detection, as unusually large or small amounts might indicate suspicious activity.
#
# ### 6. first
# - **Description**: The first name of the cardholder.
# - **Type**: String.
# - **Usage**: Can be used for identity verification or linking transactions to a specific individual.
#
# ### 7. last
# - **Description**: The last name of the cardholder.
# - **Type**: String.
# - **Usage**: Similar to `first`, this helps identify the cardholder and link transactions to an individual.
#
# ### 8. gender
# - **Description**: The gender of the cardholder.
# - **Type**: Categorical (string, e.g., "M" for male, "F" for female).
# - **Usage**: May be used for demographic analysis or to identify patterns in spending behavior based on gender.
#
# ### 9. street
# - **Description**: The street address of the cardholder.
# - **Type**: String.
# - **Usage**: Useful for verifying the cardholder's location and detecting potential fraud if transactions occur far from the cardholder's home address.
#
# ### 10. city
# - **Description**: The city where the cardholder resides.
# - **Type**: String.
# - **Usage**: Similar to `street`, this can help verify the cardholder's location and detect anomalies.
#
# ### 11. state
# - **Description**: The state or province where the cardholder resides.
# - **Type**: String.
# - **Usage**: Another geographical indicator that can help in fraud detection.
#
# ### 12. zip
# - **Description**: The ZIP code of the cardholder's residence.
# - **Type**: Numeric or string.
# - **Usage**: Useful for geolocation and detecting transactions that occur outside the cardholder's usual area.
#
# ### 13. lat
# - **Description**: The latitude coordinate of the cardholder's location.
# - **Type**: Numeric (float).
# - **Usage**: Used for geospatial analysis to determine the proximity of the transaction location to the cardholder's home.
#
# ### 14. long
# - **Description**: The longitude coordinate of the cardholder's location.
# - **Type**: Numeric (float).
# - **Usage**: Complements `lat` for geospatial analysis.
#
# ### 15. city_pop
# - **Description**: The population of the city where the cardholder resides.
# - **Type**: Numeric (integer).
# - **Usage**: May be used for demographic analysis or to identify patterns in spending behavior based on urban vs. rural areas.
#
# ### 16. job
# - **Description**: The occupation or job title of the cardholder.
# - **Type**: String.
# - **Usage**: Useful for understanding the cardholder's income level or spending habits based on their profession.
#
# ### 17. dob
# - **Description**: The date of birth of the cardholder.
# - **Type**: Date or string.
# - **Usage**: Helps calculate the cardholder's age, which can be used for demographic analysis or to identify age-related spending patterns.
#
# ### 18. trans_num
# - **Description**: A unique identifier for each transaction.
# - **Type**: String or numeric.
# - **Usage**: Ensures each transaction can be uniquely identified and tracked.
#
# ### 19. unix_time
# - **Description**: The timestamp of the transaction in Unix time format (number of seconds since January 1, 1970).
# - **Type**: Numeric (integer).
# - **Usage**: Useful for precise time-based analysis and comparisons across different systems.
#
# ### 20. merch_lat
# - **Description**: The latitude coordinate of the merchant's location.
# - **Type**: Numeric (float).
# - **Usage**: Used for geospatial analysis to determine the distance between the cardholder and the merchant.
#
# ### 21. merch_long
# - **Description**: The longitude coordinate of the merchant's location.
# - **Type**: Numeric (float).
# - **Usage**: Complements `merch_lat` for geospatial analysis.
#
# ### 22. is_fraud
# - **Description**: Indicates whether the transaction is fraudulent (1) or legitimate (0).
# - **Type**: Binary (integer, 0 or 1).
# - **Usage**: The target variable for fraud detection models. Used to train machine learning algorithms to predict fraud.
#
# ### 23. merch_zipcode
# - **Description**: The ZIP code of the merchant's location.
# - **Type**: Numeric or string.
# - **Usage**: Useful for comparing the merchant's location with the cardholder's location to detect potential fraud.
#
# ## Summary
#
# This dataset contains a mix of transactional, demographic, and geospatial data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_columns', 21)

# %%
df=pd.read_csv('cleaned.csv')
df
# Out:
#                       cc_num                             merchant  category  \
# 0           2703186189652095           fraud_Rippin, Kub and Mann         2
# 1             38859492057661                 fraud_Lind-Buckridge         2
# 2            375534208663984                  fraud_Keeling-Crist         2
# 3           4767265376804500     fraud_Stroman, Hudson and Erdman         2
# 4           6011360759745864                 fraud_Corwin-Collins         2
# ...                      ...                                  ...       ...
# 1100697  4400011257587661852                 fraud_Stiedemann Inc         2
# 1100698     6011149206456997             fraud_Abernathy and Sons         4
# 1100699     3514865930894695                 fraud_Stiedemann Ltd         4
# 1100700     2720012583106919  fraud_Reinger, Weissnat and Strosin         4
# 1100701  4292902571056973207  fraud_Langosh, Wintheiser and Hyatt         4
#
#             amt  gender                         street  \
# 0          4.97       0                 561 Perry Cove
# 1        220.11       1       594 White Dale Suite 530
# 2         41.96       1               408 Bradley Rest
# 3         94.63       0              4655 David Island
# 4         71.65       1      231 Flores Pass Suite 720
# ...         ...     ...                            ...
# 1100697   37.38       0                474 Allen Haven
# 1100698   51.70       1  8617 Holmes Terrace Suite 651
# 1100699  105.93       1     1632 Cohen Drive Suite 639
# 1100700   74.90       1           42933 Ryan Underpass
# 1100701    4.30       1           135 Joseph Mountains
#
#                              city     state    zip      lat  ...   unix_time  \
# 0                  Moravian Falls  0.004781  28654  36.0788  ...  1325376018
# 1                      Malad City  0.002517  83252  42.1808  ...  1325376051
# 2                        Doe Hill  0.006732  24433  38.4207  ...  1325376186
# 3                          Dublin  0.005638  18917  40.3750  ...  1325376248
# 4                        Edinburg  0.006732  22824  38.8432  ...  1325376308
# ...                           ...       ...    ...      ...  ...         ...
# 1100697                North Loup  0.007497  68859  41.4972  ...  1371816696
# 1100698                 Tuscarora  0.005960  21790  39.2667  ...  1371816739
# 1100699  High Rolls Mountain Park  0.005325  88325  32.9396  ...  1371816752
# 1100700                 Manderson  0.006285  57756  43.3526  ...  1371816816
# 1100701                      Sula  0.003300  59871  45.8433  ...  1371816817
#
#          merch_lat  merch_long is_fraud  merch_zipcode  age  year  month  day  \
# 0        36.011293  -82.048315        0        28705.0   30  2019      1    1
# 1        43.150704 -112.154481        0        83236.0   56  2019      1    1
# 2        38.674999  -78.632459        0        22844.0   32  2019      1    1
# 3        40.653382  -76.152667        0        17972.0   57  2019      1    1
# 4        38.948089  -78.540296        0        22644.0   71  2019      1    1
# ...            ...         ...      ...            ...  ...   ...    ...  ...
# 1100697  41.728638  -99.039660        0        68837.0   39  2020      6   21
# 1100698  38.906881  -78.246528        0        22630.0   40  2020      6   21
# 1100699  33.619513 -105.130529        0        88351.0   52  2020      6   21
# 1100700  42.788940 -103.241160        0        69367.0   39  2020      6   21
# 1100701  46.565983 -114.186110        0        59870.0   24  2020      6   21
#
#          hour
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 1100697    12
# 1100698    12
# 1100699    12
# 1100700    12
# 1100701    12
#
# [1100702 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003898 entries, 0 to 1003897
# Data columns (total 24 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   cc_num         1003898 non-null  int64
#  1   merchant       1003898 non-null  object
#  2   category       1003898 non-null  int64
#  3   amt            1003898 non-null  float64
#  4   gender         1003898 non-null  int64
#  5   street         1003898 non-null  object
#  6   city           1003898 non-null  object
#  7   state          1003898 non-null  float64
#  8   zip            1003898 non-null  int64
#  9   lat            1003898 non-null  float64
#  10  long           1003898 non-null  float64
#  11  city_pop       1003898 non-null  int64
#  12  job            1003898 non-null  float64
#  13  trans_num      1003898 non-null  object
#  14  unix_time      1003898 non-null  int64
#  15  merch_lat      1003898 non-null  float64
#  16  merch_long     1003898 non-null  float64
#  17  is_fraud       1003898 non-null  int64
#  18  merch_zipcode  1003898 non-null  float64
#  19  age            1003898 non-null  int64
#  20  year           1003898 non-null  int64
#  21  month          1003898 non-null  int64
#  22  day            1003898 non-null  int64
#  23  hour           1003898 non-null  int64
# dtypes: float64(8), int64(12), object(4)
# memory usage: 183.8+ MB

# %%
df['merchant'].unique()
# Out:
# array(['fraud_Rippin, Kub and Mann', 'fraud_Lind-Buckridge',
#        'fraud_Keeling-Crist', 'fraud_Stroman, Hudson and Erdman',
#        'fraud_Corwin-Collins', 'fraud_Herzog Ltd',
#        'fraud_Schoen, Kuphal and Nitzsche', 'fraud_Rutherford-Mertz',
#        'fraud_Kerluke-Abshire', 'fraud_Lockman Ltd',
#        'fraud_Schmidt and Sons', 'fraud_Lebsack and Sons',
#        'fraud_Mayert Group', 'fraud_Konopelski, Schneider and Hartmann',
#        'fraud_Schultz, Simonis and Little', 'fraud_Bauch-Raynor',
#        'fraud_Harris Inc', 'fraud_Kling-Grant', 'fraud_Pacocha-Bauch',
#        'fraud_Lesch Ltd', 'fraud_Kunde-Sanford', "fraud_Deckow-O'Conner",
#        'fraud_Bruen-Yost', 'fraud_Kunze Inc',
#        'fraud_Heller, Gutmann and Zieme', 'fraud_Torphy-Goyette',
#        'fraud_Balistreri-Nader', 'fraud_Bahringer, Schoen and Corkery',
#        'fraud_Hudson-Ratke', 'fraud_Heidenreich PLC',
#        'fraud_Halvorson Group', 'fraud_Harber Inc',
#        'fraud_Christiansen, Goyette and Schamberger', 'fraud_Howe Ltd',
#        'fraud_Koepp-Witting', 'fraud_Schaefer, Maggio and Daugherty',
#        'fraud_Stracke-Lemke', 'fraud_Mosciski, Ziemann and Farrell',
#        'fraud_Cartwright-Harris', "fraud_Pacocha-O'Reilly",
#        'fraud_Pfeffer LLC', 'fraud_Huels-Hahn', 'fraud_Volkman PLC',
#        'fraud_Kiehn-Emmerich', 'fraud_Kemmer-Buckridge',
#        'fraud_Goldner, Kovacek and Abbott', 'fraud_Spinka-Welch',
#        'fraud_Macejkovic-Lesch', 'fraud_Morar Inc',
#        'fraud_Eichmann, Bogan and Rodriguez',
#        'fraud_Ferry, Lynch and Kautzer', 'fraud_Huel-Langworth',
#        'fraud_Little, Gutmann and Lynch', 'fraud_Jaskolski-Dibbert',
#        'fraud_Cummings LLC', 'fraud_Osinski, Ledner and Leuschke',
#        'fraud_Reichert, Huels and Hoppe', 'fraud_Ankunding LLC',
#        'fraud_Pfeffer and Sons', 'fraud_Greenholt, Jacobi and Gleason',
#        'fraud_Connelly, Reichert and Fritsch', 'fraud_Torp-Labadie',
#        'fraud_Wolf Inc', 'fraud_Bernhard Inc',
#        'fraud_Morissette, Weber and Wiegand', 'fraud_Brekke and Sons',
#        'fraud_Mraz-Herzog', 'fraud_Padberg-Welch',
#        'fraud_Corwin-Gorczany', 'fraud_Huels-Nolan',
#        'fraud_Kutch-Hegmann', 'fraud_Mosciski, Gislason and Mertz',
#        'fraud_Schmeler Inc', 'fraud_Pouros-Conroy',
#        'fraud_Erdman-Kertzmann', 'fraud_Fisher-Schowalter',
#        'fraud_Medhurst PLC', 'fraud_Kerluke Inc', 'fraud_Stark-Batz',
#        'fraud_Gottlieb, Considine and Schultz',
#        'fraud_Adams, Kovacek and Kuhlman',
#        'fraud_Huel, Hammes and Witting', 'fraud_Grimes LLC',
#        'fraud_Rodriguez Group', 'fraud_Wuckert-Walter',
#        'fraud_Weber and Sons', 'fraud_Herman, Treutel and Dickens',
#        'fraud_Rau and Sons', 'fraud_Koss and Sons',
#        'fraud_Smitham-Schiller', 'fraud_Hills-Olson',
#        'fraud_Swaniawski, Lowe and Robel', 'fraud_McDermott-Rice',
#        'fraud_Raynor, Reinger and Hagenes', 'fraud_DuBuque LLC',
#        'fraud_Powlowski-Weimann', 'fraud_Langosh, Wintheiser and Hyatt',
#        'fraud_Baumbach, Hodkiewicz and Walsh', 'fraud_Rempel Inc',
#        'fraud_Bins-Rice', 'fraud_Emard Inc', 'fraud_Fisher Inc',
#        'fraud_Olson, Becker and Koch', "fraud_Friesen-D'Amore",
#        'fraud_Boyer PLC', 'fraud_Luettgen PLC', 'fraud_Cassin-Harvey',
#        'fraud_Funk Group', 'fraud_Reilly, Heaney and Cole',
#        'fraud_Goodwin-Nitzsche',
#        'fraud_Parisian, Schiller and Altenwerth', 'fraud_Metz-Boehm',
#        'fraud_Monahan, Bogisich and Ledner', 'fraud_Koelpin and Sons',
#        'fraud_Kuhic LLC', 'fraud_Koepp-Parker',
#        'fraud_Stehr, Jewess and Schimmel',
#        'fraud_Quitzon, Green and Bashirian',
#        'fraud_Nicolas, Hills and McGlynn', 'fraud_Friesen-Stamm',
#        'fraud_Botsford Ltd', 'fraud_Bradtke PLC',
#        'fraud_Zieme, Bode and Dooley', 'fraud_Hills-Witting',
#        'fraud_Brown-Greenholt', 'fraud_Bernhard, Grant and Langworth',
#        'fraud_Wiza, Schaden and Stark', 'fraud_Buckridge PLC',
#        'fraud_Kilback LLC', 'fraud_Kerluke, Kertzmann and Wiza',
#        'fraud_Ferry, Reichel and DuBuque',
#        'fraud_Johnston, Nikolaus and Maggio', 'fraud_Berge LLC',
#        'fraud_Conroy-Cruickshank', 'fraud_Abshire PLC', 'fraud_Doyle Ltd',
#        'fraud_McGlynn-Jaskolski', 'fraud_Bartoletti-Wunsch',
#        'fraud_Cole PLC', 'fraud_Lehner, Reichert and Mills',
#        'fraud_McCullough LLC', 'fraud_Schmitt Ltd', 'fraud_Pouros-Haag',
#        'fraud_Weimann, Kuhic and Beahan', 'fraud_Donnelly PLC',
#        'fraud_Kutch, Hermiston and Farrell',
#        'fraud_Lockman, West and Runte', 'fraud_Torp-Lemke',
#        'fraud_Rodriguez, Yost and Jenkins', 'fraud_Wiegand-Lowe',
#        'fraud_Auer-Mosciski', 'fraud_Okuneva, Schneider and Rau',
#        'fraud_Kassulke PLC', 'fraud_Dach-Nader', 'fraud_Cummings Group',
#        'fraud_Reichert, Shanahan and Hayes',
#        'fraud_Tromp, Kerluke and Glover',
#        'fraud_Bins, Balistreri and Beatty', 'fraud_Trantow PLC',
#        'fraud_Spinka Inc', 'fraud_Kuvalis Ltd', 'fraud_Dickinson Ltd',
#        'fraud_Stanton, Jakubowski and Baumbach',
#        'fraud_Rohan, White and Aufderhar',
#        'fraud_Tillman, Fritsch and Schmitt',
#        'fraud_Christiansen-Gusikowski', 'fraud_Vandervort-Funk',
#        'fraud_Jenkins, Hauck and Friesen', 'fraud_Cummerata-Jones',
#        'fraud_Reichel Inc', 'fraud_Prohaska-Murray',
#        'fraud_Parker, Nolan and Trantow', 'fraud_Volkman Ltd',
#        'fraud_Streich, Hansen and Veum', 'fraud_Kutch LLC',
#        'fraud_Barton Inc', 'fraud_Dooley-Thompson', 'fraud_Flatley Group',
#        'fraud_Turcotte-Halvorson', 'fraud_Lynch Ltd',
#        'fraud_Romaguera, Cruickshank and Greenholt', 'fraud_Gutmann Ltd',
#        'fraud_Sporer Inc', 'fraud_Runolfsson and Sons',
#        'fraud_Bahringer-Larson', 'fraud_Ledner-Pfannerstill',
#        'fraud_Heathcote LLC', 'fraud_Rowe, Batz and Goodwin',
#        'fraud_VonRueden Group', 'fraud_Schmitt Inc', 'fraud_Maggio-Fahey',
#        'fraud_Haley, Jewess and Bechtelar',
#        'fraud_Ruecker, Beer and Collier',
#        'fraud_Robel, Cummerata and Prosacco', 'fraud_Jast-McDermott',
#        'fraud_Heaney-Marquardt', 'fraud_Hudson-Grady',
#        'fraud_Towne, Walker and Borer', 'fraud_Price Inc',
#        'fraud_Terry-Huel', 'fraud_Kihn-Fritsch', 'fraud_Eichmann-Russel',
#        'fraud_Miller-Harris', 'fraud_Schumm PLC',
#        'fraud_Greenfelder, Bartoletti and Davis',
#        'fraud_Kovacek, Dibbert and Ondricka', 'fraud_Hermann-Gaylord',
#        'fraud_McDermott-Weimann', 'fraud_Welch Inc', 'fraud_Auer-West',
#        'fraud_Boehm, Predovic and Reinger', 'fraud_Dibbert and Sons',
#        'fraud_Lind, Huel and McClure', 'fraud_McCullough Group',
#        'fraud_Streich, Dietrich and Barton', "fraud_O'Keefe-Hudson",
#        'fraud_Pagac LLC', "fraud_Greenholt, O'Hara and Balistreri",
#        'fraud_Dickinson-Rempel', 'fraud_Dare-Marvin',
#        'fraud_Kris-Weimann', 'fraud_Spencer PLC', 'fraud_Stamm-Rodriguez',
#        'fraud_Langworth, Boehm and Gulgowski',
#        'fraud_Larkin, Stracke and Greenfelder',
#        'fraud_Yost, Block and Koepp', 'fraud_Bailey-Morar',
#        'fraud_Douglas, Schneider and Turner', 'fraud_Kuphal-Predovic',
#        'fraud_Parisian and Sons', 'fraud_Flatley-Durgan',
#        'fraud_Gislason Group', 'fraud_Bednar Group',
#        'fraud_Casper, Hand and Zulauf', 'fraud_Zboncak Ltd',
#        'fraud_Gerlach Inc', 'fraud_Moen, Reinger and Murphy',
#        'fraud_Kerluke, Considine and Macejkovic', 'fraud_Upton PLC',
#        'fraud_Bogisich Inc', 'fraud_Murray-Smitham', 'fraud_Frami Group',
#        'fraud_Ortiz Group', 'fraud_Goldner-Lemke',
#        'fraud_Strosin-Cruickshank', 'fraud_Hickle Group',
#        'fraud_Conroy Ltd', 'fraud_Schumm, Bauch and Ondricka',
#        'fraud_McGlynn-Heathcote', 'fraud_Miller-Hauck',
#        'fraud_Kihn, Abernathy and Douglas', 'fraud_Gutmann-Upton',
#        'fraud_Volkman-Predovic', 'fraud_Kuhn LLC',
#        'fraud_Wintheiser, Dietrich and Schimmel',
#        'fraud_Raynor, Feest and Miller', 'fraud_Bogisich-Homenick',
#        'fraud_Jast and Sons', 'fraud_Baumbach, Strosin and Nicolas',
#        'fraud_Towne, Greenholt and Koepp', "fraud_Schamberger-O'Keefe",
#        'fraud_Nienow PLC', 'fraud_Emmerich-Luettgen',
#        'fraud_Baumbach, Feeney and Morar', 'fraud_Mohr Inc',
#        'fraud_Hagenes, Kohler and Hoppe', 'fraud_Block-Parisian',
#        'fraud_Bashirian Group', 'fraud_Cremin, Hamill and Reichel',
#        'fraud_Sawayn PLC', 'fraud_Jewess LLC', 'fraud_Roberts-Beahan',
#        'fraud_Brown PLC', 'fraud_Kilback Group', 'fraud_Dach-Borer',
#        'fraud_Johnson, Runolfsdottir and Mayer', 'fraud_Smitham-Boehm',
#        'fraud_Moore, Dibbert and Koepp', 'fraud_Hackett-Lueilwitz',
#        'fraud_Hamill-Daugherty', 'fraud_Watsica, Haag and Considine',
#        'fraud_Smith-Stokes', 'fraud_Kuhic, Bins and Pfeffer',
#        'fraud_Nader-Heller', 'fraud_Kozey-Boehm',
#        'fraud_Lehner, Mosciski and King', 'fraud_Reynolds-Schinner',
#        'fraud_Durgan-Auer', 'fraud_Koss, McLaughlin and Mayer',
#        'fraud_Terry, Johns and Bins', 'fraud_Kemmer-Reinger',
#        'fraud_Larson-Moen', 'fraud_Kuhic Inc',
#        'fraud_Tillman, Dickinson and Labadie',
#        'fraud_Schmeler, Bashirian and Price',
#        'fraud_Schaefer, Fay and Hilll', 'fraud_Kling Inc',
#        'fraud_Schaefer, McGlynn and Bosco', 'fraud_Turner and Sons',
#        'fraud_Wiza LLC', 'fraud_Skiles-Ankunding', 'fraud_Kutch and Sons',
#        'fraud_Jaskolski-Vandervort', 'fraud_Ernser-Lynch',
#        'fraud_Kiehn Inc', 'fraud_Heller-Langosh',
#        'fraud_Bernier, Streich and Jewess',
#        'fraud_Labadie, Treutel and Bode',
#        'fraud_Zboncak, Rowe and Murazik', 'fraud_Stoltenberg-Beatty',
#        'fraud_Kuphal-Bartoletti', 'fraud_Rempel PLC',
#        'fraud_Denesik and Sons', 'fraud_Goyette Inc', 'fraud_Dicki Ltd',
#        'fraud_Stokes, Christiansen and Sipes',
#        'fraud_Bernier, Volkman and Hoeger',
#        'fraud_Nitzsche, Kessler and Wolff', 'fraud_Gibson-Deckow',
#        'fraud_Douglas-White', 'fraud_Wilkinson Ltd', 'fraud_Murray Ltd',
#        'fraud_McKenzie-Huels', 'fraud_Runte-Mohr',
#        'fraud_Roob, Conn and Tremblay', 'fraud_Boyer-Reichert',
#        'fraud_Waters-Cruickshank', 'fraud_Kunze, Larkin and Mayert',
#        'fraud_Bednar Inc', 'fraud_Schimmel-Olson',
#        'fraud_Lubowitz, Terry and Stracke', 'fraud_Schoen-Quigley',
#        'fraud_Kihn-Schuster', 'fraud_Padberg-Rogahn', 'fraud_Lynch-Mohr',
#        'fraud_Hilpert-Conroy', 'fraud_Jacobi Inc', 'fraud_Gulgowski LLC',
#        'fraud_Schuppe, Nolan and Hoeger',
#        'fraud_Cormier, Stracke and Thiel', 'fraud_Pollich LLC',
#        'fraud_Bernier and Sons', 'fraud_Wilkinson PLC',
#        'fraud_Kling-Ernser', 'fraud_Reichert, Rowe and Mraz',
#        "fraud_O'Connell, Botsford and Hand", 'fraud_Little-Gleichner',
#        'fraud_Champlin and Sons', 'fraud_Hoppe-Parisian',
#        'fraud_Schuppe LLC', 'fraud_Emmerich-Rau', 'fraud_Beier LLC',
#        'fraud_Champlin-Casper', 'fraud_Gerhold LLC', 'fraud_Renner Ltd',
#        'fraud_Gaylord-Powlowski', 'fraud_Prosacco, Kreiger and Kovacek',
#        'fraud_Eichmann-Kilback', "fraud_O'Hara-Wilderman",
#        'fraud_Terry Ltd', 'fraud_Beier and Sons', 'fraud_Mohr-Bayer',
#        'fraud_Simonis-Prohaska', 'fraud_Breitenberg-Hermiston',
#        'fraud_Brown Inc', 'fraud_Fahey Inc',
#        'fraud_Boehm, Block and Jakubowski',
#        'fraud_Mante, Luettgen and Hackett',
#        'fraud_Turcotte, Batz and Buckridge', 'fraud_Beier-Hyatt',
#        'fraud_Medhurst Inc', 'fraud_Connelly-Carter',
#        'fraud_Hettinger, McCullough and Fay',
#        'fraud_Pouros, Walker and Spencer', 'fraud_Kub PLC',
#        'fraud_Watsica LLC', 'fraud_Stiedemann Ltd',
#        'fraud_Hauck, Dietrich and Funk', 'fraud_Labadie LLC',
#        'fraud_Friesen Inc', 'fraud_Crist, Jakubowski and Littel',
#        'fraud_Hodkiewicz, Prohaska and Paucek',
#        'fraud_McDermott, Osinski and Morar', 'fraud_Fritsch and Sons',
#        'fraud_Swaniawski, Nitzsche and Welch', 'fraud_Gleason-Macejkovic',
#        'fraud_Windler, Goodwin and Kovacek', 'fraud_Erdman-Durgan',
#        'fraud_Bahringer, Bergnaum and Quitzon',
#        'fraud_Becker, Harris and Harvey', 'fraud_Monahan-Morar',
#        'fraud_Johns Inc', 'fraud_Mosciski Group', 'fraud_Abbott-Steuber',
#        'fraud_Schaefer Ltd', 'fraud_Weimann-Lockman', 'fraud_Kub-Heaney',
#        'fraud_Ratke and Sons', 'fraud_Beer-Jast',
#        'fraud_Kautzer and Sons', 'fraud_Feil-Morar',
#        'fraud_Johnston-Casper', 'fraud_Medhurst, Labadie and Gottlieb',
#        "fraud_Lesch, D'Amore and Brown", 'fraud_Bins-Howell',
#        'fraud_Hartmann, Rowe and Hermann', 'fraud_Towne LLC',
#        'fraud_Lynch-Wisozk', 'fraud_Kutch-Ferry',
#        'fraud_Bradtke, Torp and Bahringer', 'fraud_Homenick LLC',
#        'fraud_Zemlak, Tillman and Cremin',
#        'fraud_Schneider, Hayes and Nikolaus',
#        'fraud_Schumm, McLaughlin and Carter', 'fraud_Nader-Maggio',
#        'fraud_Haley, Batz and Auer', 'fraud_Yost-Rogahn',
#        'fraud_Schoen, Nienow and Bauch',
#        'fraud_Ledner, Hartmann and Feest', 'fraud_Collier LLC',
#        'fraud_Schuppe-Schuppe', 'fraud_Greenholt Ltd',
#        'fraud_Gottlieb-Hansen', 'fraud_Bechtelar-Rippin',
#        "fraud_Hamill-D'Amore", 'fraud_Swift PLC',
#        'fraud_Cronin, Kshlerin and Weber',
#        'fraud_Romaguera, Wehner and Tromp',
#        'fraud_Walter, Hettinger and Kessler',
#        'fraud_Feil, Hilpert and Koss', 'fraud_Thiel PLC',
#        'fraud_White and Sons', 'fraud_Mueller, Gerhold and Mueller',
#        'fraud_Botsford and Sons', 'fraud_Kris-Padberg',
#        'fraud_Yost, Schamberger and Windler', 'fraud_Bednar PLC',
#        'fraud_Botsford PLC', 'fraud_Runolfsdottir, Mueller and Hand',
#        'fraud_Kuphal-Toy', 'fraud_Bahringer-Streich',
#        'fraud_Crona and Sons', 'fraud_Prosacco LLC', 'fraud_Schiller Ltd',
#        'fraud_Waelchi-Wolf', 'fraud_Herman Inc',
#        'fraud_McCullough, Hudson and Schuster', 'fraud_Baumbach Ltd',
#        'fraud_Schiller, Blanda and Johnson', 'fraud_Jakubowski Inc',
#        'fraud_Cartwright PLC', 'fraud_Kerluke PLC', 'fraud_Reilly LLC',
#        'fraud_Cruickshank-Mills', 'fraud_Altenwerth, Cartwright and Koss',
#        'fraud_Effertz, Welch and Schowalter',
#        'fraud_Klocko, Runolfsdottir and Breitenberg',
#        'fraud_Schroeder, Hauck and Treutel', 'fraud_Lemke-Gutmann',
#        'fraud_Graham, Hegmann and Hammes', 'fraud_Reilly and Sons',
#        'fraud_Stark-Koss', "fraud_O'Keefe-Wisoky", 'fraud_Daugherty LLC',
#        'fraud_Denesik, Powlowski and Pouros', 'fraud_Rippin-VonRueden',
#        'fraud_Hills-Boyer', 'fraud_Cormier LLC', 'fraud_Erdman-Ebert',
#        'fraud_Bogisich-Weimann', 'fraud_Gutmann, McLaughlin and Wiza',
#        'fraud_Little Ltd', 'fraud_Bode-Rempel',
#        'fraud_Kutch, Steuber and Gerhold', 'fraud_Kessler Inc',
#        'fraud_Rolfson-Kunde', 'fraud_Marvin-Lind', 'fraud_Barrows PLC',
#        'fraud_Ziemann-Waters', 'fraud_Goyette, Howell and Collier',
#        'fraud_Reinger, Weissnat and Strosin',
#        'fraud_Heathcote, Yost and Kertzmann', 'fraud_Dibbert-Green',
#        'fraud_Will Ltd', 'fraud_Kutch-Wilderman',
#        'fraud_Dare, Fritsch and Zboncak',
#        'fraud_Hermiston, Russel and Price', 'fraud_Schmidt-Larkin',
#        'fraud_Leannon-Ward', 'fraud_Lang, Towne and Schuppe',
#        'fraud_Weber, Thiel and Hammes',
#        'fraud_Hahn, Bahringer and McLaughlin',
#        'fraud_Koss, Hansen and Lueilwitz',
#        'fraud_Roberts, Ryan and Smith', 'fraud_Bode-Schuster',
#        'fraud_Douglas, DuBuque and McKenzie', 'fraud_Hackett Group',
#        'fraud_Schmeler-Howe', 'fraud_Predovic Inc', 'fraud_Langworth LLC',
#        'fraud_Klocko LLC', 'fraud_Bernhard-Lesch',
#        'fraud_Satterfield-Lowe', 'fraud_Runte, Green and Emard',
#        'fraud_Lowe, Dietrich and Erdman', 'fraud_Jast Ltd',
#        'fraud_Welch, Rath and Koepp', 'fraud_Skiles LLC',
#        'fraud_Ernser-Feest', 'fraud_Klein Group',
#        'fraud_Torp, Muller and Borer', 'fraud_Shanahan-Lehner',
#        'fraud_Hermann and Sons', 'fraud_Kuhn Group', 'fraud_Bins-Tillman',
#        'fraud_Ankunding-Carroll', 'fraud_Zulauf LLC',
#        'fraud_Hahn, Douglas and Schowalter',
#        'fraud_Witting, Beer and Ernser', 'fraud_Morissette LLC',
#        'fraud_Berge, Kautzer and Harris', 'fraud_Berge-Hills',
#        'fraud_Zboncak LLC', 'fraud_Turner, Ziemann and Lehner',
#        'fraud_Padberg-Sauer', 'fraud_Schulist Ltd', 'fraud_Hammes-Beatty',
#        'fraud_Osinski Inc', 'fraud_Berge-Ullrich',
#        'fraud_Wuckert-Goldner', 'fraud_Kertzmann LLC',
#        'fraud_Daugherty, Pouros and Beahan', 'fraud_Dooley Inc',
#        'fraud_Armstrong, Walter and Gottlieb', 'fraud_Torphy-Kertzmann',
#        'fraud_Conroy-Emard', 'fraud_Donnelly LLC',
#        'fraud_Gleason and Sons', 'fraud_Roberts, Daniel and Macejkovic',
#        'fraud_Turner LLC', 'fraud_Crooks and Sons', 'fraud_Waelchi Inc',
#        'fraud_Hoppe, Harris and Bednar', 'fraud_Effertz LLC',
#        'fraud_Lubowitz-Walter', 'fraud_Moore, Williamson and Emmerich',
#        'fraud_Hyatt-Blick', 'fraud_Carroll PLC', 'fraud_Lemke and Sons',
#        'fraud_Treutel-King', 'fraud_Fadel-Hilpert',
#        'fraud_Altenwerth-Kilback', 'fraud_Kulas Group',
#        'fraud_Ruecker-Mayert', 'fraud_Hintz, Bauch and Smith',
#        'fraud_Sporer-Keebler', 'fraud_Hirthe-Beier',
#        'fraud_Streich, Rolfson and Wilderman', 'fraud_Streich Ltd',
#        'fraud_Schoen Ltd', 'fraud_Deckow-Dare', 'fraud_Windler LLC',
#        'fraud_Nolan-Williamson', 'fraud_Roob-Okuneva',
#        'fraud_Lakin, Ferry and Beatty', 'fraud_Gottlieb Group',
#        'fraud_Harris Group', 'fraud_Fritsch LLC',
#        'fraud_Corwin-Romaguera', 'fraud_Dietrich-Fadel',
#        'fraud_Kling, Howe and Schneider', 'fraud_Kozey-Kuhlman',
#        'fraud_Graham and Sons', 'fraud_Jacobi and Sons',
#        'fraud_Eichmann, Hayes and Treutel',
#        'fraud_Brown, Homenick and Lesch', 'fraud_Wisozk and Sons',
#        'fraud_Erdman-Schaden', 'fraud_Durgan, Gislason and Spencer',
#        'fraud_Friesen-Ortiz', 'fraud_Morissette-Schaefer',
#        'fraud_Nienow, Ankunding and Collier',
#        'fraud_Cole, Hills and Jewess',
#        'fraud_Conroy, Balistreri and Gorczany',
#        'fraud_Reichel, Bradtke and Blanda',
#        "fraud_O'Reilly, Mohr and Purdy", 'fraud_Ullrich Ltd',
#        'fraud_Heller PLC', 'fraud_Schroeder Group', 'fraud_Boyer-Haley',
#        'fraud_Dare, Casper and Bartoletti',
#        'fraud_Medhurst, Cartwright and Ebert', 'fraud_Quitzon-Goyette',
#        'fraud_Wilkinson LLC', 'fraud_Romaguera and Sons',
#        'fraud_Huel Ltd', 'fraud_Thompson-Gleason', 'fraud_Zemlak Group',
#        'fraud_Dare-Gibson', 'fraud_Bartoletti and Sons',
#        'fraud_Block-Hauck', 'fraud_Howe PLC', 'fraud_Leffler-Goldner',
#        'fraud_Tillman LLC', 'fraud_Pacocha-Weissnat',
#        'fraud_Jerde-Hermann', 'fraud_Kihn, Brakus and Goyette',
#        'fraud_Kirlin and Sons', 'fraud_Hills, Hegmann and Schaefer',
#        'fraud_Veum-Koelpin', 'fraud_Schroeder, Wolff and Hermiston',
#        'fraud_Bahringer, Osinski and Block', 'fraud_Friesen Ltd',
#        'fraud_Kilback and Sons', 'fraud_Ebert-Daugherty',
#        'fraud_Hermiston, Pacocha and Smith', 'fraud_Larkin Ltd',
#        'fraud_Auer LLC', 'fraud_Metz, Russel and Metz', 'fraud_Fadel Inc',
#        'fraud_Daugherty-Thompson',
#        'fraud_Wuckert, Wintheiser and Friesen', 'fraud_Kihn Inc',
#        'fraud_Romaguera Ltd', 'fraud_Parker-Kunde', 'fraud_Barton LLC',
#        'fraud_Kassulke Inc', 'fraud_McLaughlin, Armstrong and Koepp',
#        'fraud_Abernathy and Sons', 'fraud_Monahan, Hermann and Johns',
#        'fraud_Bahringer Group', 'fraud_Morissette PLC',
#        'fraud_Block Group', 'fraud_Goyette-Gerhold',
#        'fraud_Adams-Barrows', "fraud_O'Connell-Ullrich",
#        'fraud_Kozey-McDermott', 'fraud_Reichel LLC', 'fraud_Thiel-Thiel',
#        'fraud_Rau-Robel', 'fraud_Haley Group', 'fraud_Stamm-Witting',
#        'fraud_Abbott-Rogahn', 'fraud_Ritchie, Bradtke and Stiedemann',
#        'fraud_Spencer-Runolfsson', 'fraud_Turcotte, McKenzie and Koss',
#        'fraud_Nienow, Barrows and Romaguera', 'fraud_Shields-Wunsch',
#        'fraud_Goyette-Herzog', 'fraud_Marks Inc', 'fraud_Shields Inc',
#        'fraud_Hayes, Marquardt and Dibbert',
#        'fraud_Swaniawski, Bahringer and Ledner', 'fraud_Roob LLC',
#        'fraud_Mante Group', 'fraud_Rutherford, Homenick and Bergstrom',
#        'fraud_Harris, Gusikowski and Heaney', 'fraud_Hintz-Bruen',
#        'fraud_Turner, Ruecker and Parisian', 'fraud_Ruecker Group',
#        'fraud_Johns-Hoeger', 'fraud_Hagenes, Hermann and Stroman',
#        'fraud_Reichert-Weissnat', 'fraud_Hyatt, Russel and Gleichner',
#        'fraud_Cummerata-Hilpert', 'fraud_Thiel Ltd',
#        'fraud_Williamson LLC', 'fraud_Champlin, Rolfson and Connelly',
#        'fraud_Fadel, Mertz and Rippin',
#        'fraud_Jones, Sawayn and Romaguera', 'fraud_Leannon-Nikolaus',
#        'fraud_Tromp Group', 'fraud_Bauch-Blanda', 'fraud_Kovacek Ltd',
#        'fraud_Haag-Blanda', 'fraud_Connelly PLC',
#        'fraud_Willms, Kris and Bergnaum', 'fraud_Kutch Group',
#        'fraud_Kohler, Lindgren and Koelpin', 'fraud_Heller-Abshire',
#        'fraud_Swift, Bradtke and Marquardt', 'fraud_Stiedemann Inc',
#        'fraud_Larson, Quitzon and Spencer', 'fraud_Rau-Grant',
#        'fraud_Kilback, Nitzsche and Leffler', 'fraud_Jakubowski Group',
#        'fraud_Paucek-Wiza', 'fraud_Kessler Group',
#        'fraud_Breitenberg LLC', 'fraud_Collier Inc',
#        'fraud_Ritchie, Oberbrunner and Cremin', 'fraud_Kris-Kertzmann',
#        'fraud_Rowe-Vandervort'], dtype=object)

# %% [markdown]
# ## the merchant feature containd the names of marchents

# %%
df.drop(['merchant'], axis=1, inplace=True)

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.select_dtypes(include='number').corr(method='spearman'), annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# # from the heatmap got
# 1. the col `zip` has high corelation with `long`, `march_long`, `march_zipcode` that means `zip` have same info in the 3 columns
# 2. the col `lat` has high corr with  `march_zipcode` that means `lat` has the same info in `march_zipcode`
# 3. the col `long` has high corr with  `zip`, `march_zipcode` that means `long` has the info in `march_zipcode`,`zip`
# 4. the col `unix_time` has high corr with  `year`, `month` that means `unix_time` has the info in `year`, `month`
# 5. the col `unix_time` has high corr with  `year`, `month` that means `unix_time` has the info in `year`, `month`
# 6. the col `merch_lat` has high corr with  `state`, `zip`, `lat`, `city_pop` that means `merch_lat` has the info in `state`, `zip`, `lat`, `city_pop`
# 7. the col `merch_long` has high corr with  `state`, `zip`, `long` that means `merch_lat` has the info in `state`, `zip`, `long`
# 8.  the col `merch_zipcode` has high corr with  `state`, `zip`, `lat`, `long`, `march_long` that means `merch_lat` has the info in `state`, `zip`, `lat`, `march_long`
#
# ## when those columns have high  corelation with thereselfs will choose one instead of all that have high reltion not to make the model overfit

# %%
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='is_fraud', data=df)

# Add the counts on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                textcoords='offset points')

# # Customize the plot
ax.set_title('Count of Fraudulent Transactions')
ax.set_xlabel('Is Fraud')
ax.set_ylabel('Count')

# Show the plot
plt.show()

# %% [markdown]
# ## the data has 1094339 non-fraud and 6363 fraud transaction the data is biased to be non-fraud

# %%
fig, ax = plt.subplots()

# Create the histogram
ax.hist(df['age'], bins=10, edgecolor='black')

# Customize the plot
ax.set_title('Histogram of Age')
ax.set_xlabel('Age')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# # the age is normally destributed with right skewness

# %%
sns.scatterplot(x='is_fraud', y='age', data=df)
# Out:
# <Axes: xlabel='is_fraud', ylabel='age'>

# %% [markdown]
# # there is no relation between `age` and `fruade`

# %%
# Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['amt'])

# Customize the plot
plt.title('Boxplot of Amount')
plt.xlabel('Amount')

# Show the plot
plt.show()

# %%
df['amt'].describe()
# Out:
# count    1.100702e+06
# mean     7.024263e+01
# std      1.614206e+02
# min      1.000000e+00
# 25%      9.640000e+00
# 50%      4.754000e+01
# 75%      8.316000e+01
# max      2.894890e+04
# Name: amt, dtype: float64

# %%
ax=sns.countplot(x='category', data=df)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                textcoords='offset points')

# %%
# Create a new column combining 'category' and 'is_fraud'
df['category_fraud'] = df.apply(lambda x: f"{x['category']} - {'Fraud' if x['is_fraud'] == 1 else 'Non-Fraud'}", axis=1)

# Create the count plot
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='category', hue='is_fraud', data=df)

# Annotate the bars
for p in ax.patches:
    height = p.get_height()
    if not np.isnan(height):  # Check if the height is not NaN
        ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2., height), 
                    ha='center', va='bottom', fontsize=12, color='black', xytext=(0, 5), 
                    textcoords='offset points')

# Set labels and title
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Comparison of Fraud and Non-Fraud Counts by Category')
plt.legend(title='Fraud', loc='upper right', labels=['Non-Fraud', 'Fraud'])

# Show the plot
plt.show()

# %%
ax=sns.countplot(x='year', data=df)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                textcoords='offset points')

# %%
ax=sns.countplot(x='month', data=df)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                textcoords='offset points')

# %%
df['day'] = (df['day'] - 1) % 7 + 1

# %%
ax=sns.countplot(x='day', data=df)
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                textcoords='offset points')

# %%
df.drop(columns=['long', 'merch_long', 'merch_zipcode','unix_time','year', 'state', 'zip', 'lat', 'city_pop'], axis=1,inplace=True)

# %%
len(df.columns)
# Out:
# 14

# %%
df
# Out:
#                       cc_num  category     amt  gender  \
# 0           2703186189652095         2    4.97       0
# 1             38859492057661         2  220.11       1
# 2            375534208663984         2   41.96       1
# 3           4767265376804500         2   94.63       0
# 4           6011360759745864         2   71.65       1
# ...                      ...       ...     ...     ...
# 1100697  4400011257587661852         2   37.38       0
# 1100698     6011149206456997         4   51.70       1
# 1100699     3514865930894695         4  105.93       1
# 1100700     2720012583106919         4   74.90       1
# 1100701  4292902571056973207         4    4.30       1
#
#                                 street                      city       job  \
# 0                       561 Perry Cove            Moravian Falls  0.001696
# 1             594 White Dale Suite 530                Malad City  0.011834
# 2                     408 Bradley Rest                  Doe Hill  0.000000
# 3                    4655 David Island                    Dublin  0.011686
# 4            231 Flores Pass Suite 720                  Edinburg  0.012381
# ...                                ...                       ...       ...
# 1100697                474 Allen Haven                North Loup  0.014447
# 1100698  8617 Holmes Terrace Suite 651                 Tuscarora  0.015066
# 1100699     1632 Cohen Drive Suite 639  High Rolls Mountain Park  0.005601
# 1100700           42933 Ryan Underpass                 Manderson  0.004062
# 1100701           135 Joseph Mountains                      Sula  0.005158
#
#                                 trans_num  merch_lat  is_fraud  age  month  \
# 0        0b242abb623afc578575680df30655b9  36.011293         0   30      1
# 1        a1a22d70485983eac12b5b88dad1cf95  43.150704         0   56      1
# 2        a41d7549acf90789359a9aa5346dcb46  38.674999         0   32      1
# 3        189a841a0a8ba03058526bcfe566aab5  40.653382         0   57      1
# 4        6d294ed2cc447d2c71c7171a3d54967c  38.948089         0   71      1
# ...                                   ...        ...       ...  ...    ...
# 1100697  9a7ea2625cf8303efe34e3c09546868f  41.728638         0   39      6
# 1100698  278000d2e0d2277d1de2f890067dcc0a  38.906881         0   40      6
# 1100699  483f52fe67fabef353d552c1e662974c  33.619513         0   52      6
# 1100700  d667cdcbadaaed3da3f4020e83591c83  42.788940         0   39      6
# 1100701  8f7c8e4ab7f25875d753b422917c98c9  46.565983         0   24      6
#
#          day  hour
# 0          1     0
# 1          1     0
# 2          1     0
# 3          1     0
# 4          1     0
# ...      ...   ...
# 1100697   21    12
# 1100698   21    12
# 1100699   21    12
# 1100700   21    12
# 1100701   21    12
#
# [1100702 rows x 14 columns]

# %%
df.to_csv('cleaned2.csv', index=False)
